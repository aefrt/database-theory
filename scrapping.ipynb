# %% [markdown]
# Импортирую библиотеки:

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# [Список US-прокси](https://www.us-proxy.org)
#
# [GitHub repository](https://github.com/dmitri-vlasov/aggregator)

# %%
http_proxy = "http://162.214.118.137:80"
https_proxy = "http://207.47.68.58:21231"
proxies_dict = {
    "http": http_proxy,
    "https": https_proxy
}

# %%
response = requests.get('https://www.vons.com/shop/aisles.2053.html#', proxies=proxies_dict)

# %% [markdown]
# Почему-то прокси не работает... Тогда просто скачаю HTML-код!

# %%
# !ls

# %%
html_code = open("vons_code.html").read()
html_code = response.text

# %%
print(html_code)
# Out:
# <!DOCTYPE HTML>
# <html lang="en">
# <head><script src="/ueene-suffe-and-swort-it-know-tenda-Enter-I-dist" async></script>
#     <!-- <meta http-equiv="content-type" content="text/html; charset=UTF-8" -->
#     <meta http-equiv="X-UA-Compatible" content="IE=edge; charset=UTF-8"/>
#
#     <meta http-equiv="Content-Security-Policy" content="default-src 'self' 'unsafe-inline' https://* 'unsafe-eval';
#           img-src 'self' https://* data: ;
#           style-src 'self' 'unsafe-inline' https://*;
#           child-src 'self' 'unsafe-inline' https://* 'unsafe-eval' blob: ;"/>
#
#
#     <meta name="template" content="unified-content-page"/>
#
#
#
#
#
#
#
#
# 	<title>Categories - Online Groceries | Vons</title>
#
#
# 	<meta name="description" content="Shop Categories direct from Vons. Browse our selection and order groceries for flexible Delivery or convenient Drive Up and Go to fit your schedule."/>
#
#
# 	<link rel="canonical" href="https://www.vons.com/shop/aisles.2053.html"/>
#
#
#
# ...

# %%
soup = BeautifulSoup(html_code, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html lang="en">
#  <head>
#   <script async="" src="/ueene-suffe-and-swort-it-know-tenda-Enter-I-dist">
#   </script>
#   <!-- <meta http-equiv="content-type" content="text/html; charset=UTF-8" -->
#   <meta content="IE=edge; charset=UTF-8" http-equiv="X-UA-Compatible"/>
#   <meta content="default-src 'self' 'unsafe-inline' https://* 'unsafe-eval';
#           img-src 'self' https://* data: ;
#           style-src 'self' 'unsafe-inline' https://*;
#           child-src 'self' 'unsafe-inline' https://* 'unsafe-eval' blob: ;" http-equiv="Content-Security-Policy"/>
#   <meta content="unified-content-page" name="template"/>
#   <title>
#    Categories - Online Groceries | Vons
#   </title>
#   <meta content="Shop Categories direct from Vons. Browse our selection and order groceries for flexible Delivery or convenient Drive Up and Go to fit your schedule." name="description"/>
#   <link href="https://www.vons.com/shop/aisles.2053.html" rel="canonical"/>
# ...

# %% [markdown]
# Проанализировав вручную HTML-код, находим, что тег `div` с классом `col-12 col-sm-12 col-md-4 col-lg-4 col-xl-3` содержит названия категорий + краткий список подкатегорий. Найдем все такие категории и посмотрим на нулевой элемент в массиве. Если субкатегории нужны, придется перейти по `len(soups)` ссылкам, иначе достаточно будет только названий категорий, а на субкатегории вообще пофиг пока.

# %%
# len(soups)

# %%
soups = soup.find_all('div', 'col-12 col-sm-12 col-md-4 col-lg-4 col-xl-3')
soups
# Out:
# [<div class="col-12 col-sm-12 col-md-4 col-lg-4 col-xl-3">
#  <a class="aisle-two" href="/shop/aisles/baby-care.2053.html" title="">
#  <div class="product-grid">
#  <h2 class="product-title text-uppercase">Baby Care</h2>
#  <div class="background-grey">
#  <img alt="" class="product-image" role="presentation" src="//images.albertsons-media.com/is/image/ABS/L2_1_1?$ecom-aisles-tile-png-alpha$"/>
#  </div>
#  <img alt="" aria-hidden="true" class="chevron-right" role="presentation" src="/etc/designs/wcax-commons/images/icons/Across_Icon.svg"/>
#  </div>
#  </a>
#  <ul class="product-subcats">
#  <li><a href="/shop/aisles/baby-care/baby-bath-skin-care.2053.html">Baby Bath &amp; Skin Care</a></li>
#  <li><a href="/shop/aisles/baby-care/diapers-wipes.2053.html">Diapers &amp; Wipes</a></li>
#  <li><a href="/shop/aisles/baby-care/formula-baby-food.2053.html">Formula &amp; Baby Food</a></li>
#  </ul>
# ...

# %% [markdown]
# Мы видим, что тег `h2` класса `product-title text-uppercase` содердит название категории. Субкатегории же находятся в тегах `a` со второго по последний.

# %%
soups[0]
# Out:
# <div class="col-12 col-sm-12 col-md-4 col-lg-4 col-xl-3">
# <a class="aisle-two" href="/shop/aisles/baby-care.2053.html" title="">
# <div class="product-grid">
# <h2 class="product-title text-uppercase">Baby Care</h2>
# <div class="background-grey">
# <img alt="" class="product-image" role="presentation" src="//images.albertsons-media.com/is/image/ABS/L2_1_1?$ecom-aisles-tile-png-alpha$"/>
# </div>
# <img alt="" aria-hidden="true" class="chevron-right" role="presentation" src="/etc/designs/wcax-commons/images/icons/Across_Icon.svg"/>
# </div>
# </a>
# <ul class="product-subcats">
# <li><a href="/shop/aisles/baby-care/baby-bath-skin-care.2053.html">Baby Bath &amp; Skin Care</a></li>
# <li><a href="/shop/aisles/baby-care/diapers-wipes.2053.html">Diapers &amp; Wipes</a></li>
# <li><a href="/shop/aisles/baby-care/formula-baby-food.2053.html">Formula &amp; Baby Food</a></li>
# </ul>
# ...

# %%
soups[0].find('h2', 'product-title text-uppercase').text
# Out:
# 'Baby Care'

# %%
soups[0].find_all('a')[1:]
# Out:
# [<a href="/shop/aisles/baby-care/baby-bath-skin-care.2053.html">Baby Bath &amp; Skin Care</a>,
#  <a href="/shop/aisles/baby-care/diapers-wipes.2053.html">Diapers &amp; Wipes</a>,
#  <a href="/shop/aisles/baby-care/formula-baby-food.2053.html">Formula &amp; Baby Food</a>,
#  <a aria-label="View all - Baby Care" class="view-all-subcats" href="/shop/aisles/baby-care.2053.html">View All</a>]

# %%
categories_and_subcategories = {}

# %%
for category_and_subcategory in soups:
    category = category_and_subcategory.find('h2', 'product-title text-uppercase').text
    subcategories = category_and_subcategory.find_all('a')[1:]
    subcategories_text = []
    for subcategory in subcategories:
        subcategories_text.append(subcategory.text)
    categories_and_subcategories[category] = subcategories_text

# %%
categories_and_subcategories
# Out:
# {'Baby Care': ['Baby Bath & Skin Care',
#   'Diapers & Wipes',
#   'Formula & Baby Food',
#   'View All'],
#  'Beverages': ['Coffee',
#   'Energy Drinks & Shots',
#   'Juice & Smoothies',
#   'View All'],
#  'Bread & Bakery': ['Bagels & Muffins',
#   'Baguettes & French Bread',
#   'Bakery Catering Trays',
#   'View All'],
#  'Breakfast & Cereal': ['Breakfast Bars & Bites',
#   'Instant Breakfast Drink',
#   'View All'],
#  'Canned Goods & Soups': ['Canned Seafood & Fish',
#   'Soups & Ramen',
#   '',
#   'View All'],
#  'Condiments, Spice & Bake': ['Jam,Spreads & Condiments',
#   'Seasoning,Spices & Herbs',
#   'Baking Ingredients',
#   'View All'],
#  'Cookies, Snacks & Candy': ['Cookies', 'Crackers', '', 'View All'],
#  'Dairy, Eggs & Cheese': ['Eggs', 'Milk & Cream', 'Cheese', 'View All'],
#  'Deli': ['Deli Cheese', 'Deli Dips & Hummus', 'Deli Meat', 'View All'],
#  'Flowers': ['View All'],
#  'Frozen Foods': ['Frozen Meals & Sides',
#   'Frozen Vegetables',
# ...

# %% [markdown]
# Возникла проблема с `View all` — вот как выгрузить ссылку на View all!

# %%
link = soups[0].find_all('a')[-1]['href']
link
# Out:
# '/shop/aisles/baby-care.2053.html'

# %% [markdown]
# Итак, тогда создам массив с HTML-кодами страниц категорий с субкатегориями. Работает больше 2 min, не успевает с одним бесплатным прокси :(
#
# Должно работать 20s * 19... Где-то 6 минут 30 секунд...

# %%
http_proxy = "http://162.214.118.137:80"
https_proxy = "http://137.220.55.91:3131"
proxies_dict = {
    "http": http_proxy,
    "https": https_proxy
}

# %%
categories_pages = []

# %% [markdown]
# ##### Попробую применить [Selenium](https://www.lambdatest.com/blog/how-to-get-page-source-in-selenium-webdriver/)
#
# Вот с [этим](http://free-proxy.cz/ru/proxylist/country/US/https/ping/all) прокси все заработало!!!! за 36s, selenium нн!!

# %%
for x in soups:
    link_cur = 'https://www.vons.com' + x.find_all('a')[-1]['href']
    response_cur = requests.get(link_cur, proxies=proxies_dict)
    categories_pages.append(BeautifulSoup(response_cur.text, 'html.parser'))

# %% [markdown]
# Итак, если скачать вручную HTML-код, это все работает! Осталось научиться запускать алгоритм не вручную.

# %%
care_soup = BeautifulSoup(open('./baby_care.html').read(), parser='html.parser')
#print(care_soup.prettify())
care_soups = care_soup.find_all("h2", "aisle-category")
care_soups[0].text
# Out:
# 'Formula & Baby Food'

# %% [markdown]
# Теперь попробую все-таки анализировать то что получается через `response_cur` вот это вот все:

# %%
categories_pages[0].find_all('h2', 'aisle-category')[0].text
# Out:
# 'Formula & Baby Food'

# %% [markdown]
# Вот и сказочке конец!

# %%
import requests
from bs4 import BeautifulSoup

http_proxy = "http://162.214.118.137:80"
https_proxy = "http://137.220.55.91:3131"
proxies_dict = {
    "http": http_proxy,
    "https": https_proxy
}

response = requests.get('https://www.vons.com/shop/aisles.2053.html#', proxies=proxies_dict)
html_code = response.text
soup = BeautifulSoup(html_code, 'html.parser')

soups = soup.find_all('div', 'col-12 col-sm-12 col-md-4 col-lg-4 col-xl-3')

categories_and_subcategories = {}
for category_and_subcategory in soups:
    category = category_and_subcategory.find('h2', 'product-title text-uppercase').text
    link_cur = 'https://www.vons.com' + category_and_subcategory.find_all('a')[-1]['href']
    response_cur = requests.get(link_cur, proxies=proxies_dict)
    subcategories = BeautifulSoup(response_cur.text, 'html.parser').find_all('h2', 'aisle-category')
    subcategories_text = []
    for subcategory in subcategories:
        subcategories_text.append(subcategory.text)
    categories_and_subcategories[category] = subcategories_text

categories_and_subcategories
# Out:
# {'Baby Care': ['Formula & Baby Food',
#   'Diapers & Wipes',
#   'Baby Bath & Skin Care',
#   'Baby Accessories'],
#  'Beverages': ['Juice & Smoothies',
#   'Coffee',
#   'Soft Drinks',
#   'Tea',
#   'Water & Sparkling Water',
#   'Energy Drinks & Shots',
#   'Sports Drinks',
#   'Kombucha',
#   'Coconut Water',
#   'Cocoa & Hot Chocolate'],
#  'Bread & Bakery': ['Cakes & Cupcakes',
#   'Cookies & Bakery Snacks',
#   'Desserts & Cheesecakes',
#   'Baguettes & French Bread',
#   'Breakfast & Donuts',
#   'Buns & Rolls',
#   'Sandwich Breads',
#   'Bagels & Muffins',
#   'Pitas & Flatbreads',
#   'Bakery Catering Trays'],
#  'Breakfast & Cereal': ['Cereal',
#   'Frozen Breakfast',
#   'Breakfast Bars & Bites',
#   'Pancake & Waffle Mix',
#   'Syrup',
#   'Toaster Pastries',
#   'Instant Breakfast Drink'],
#  'Canned Goods & Soups': ['Soups & Ramen',
#   'Canned Vegetables',
#   'Canned Seafood & Fish',
#   'Canned Beans',
#   'Canned Tomatoes',
#   'Canned Fruit',
# ...

# %% [markdown]
# TODO():
#
# - Добавить 3 категорию (найти ее в исходном коде; JSON в Chrome; сначала будет бейзлайн в моем стиле, а дальше я перепишу как нужно для проекта)
#
# - Прокси норм (see Telegram)
#
# - В DB добавить (хз как; но видимо как я и думал там создается строка и пишется ADD VALUES + str + ...)
#
# - Привести код к стандартному виду (see `get_supplier_categories` in `soriana.py`; lxml xpath что такое yield)

# %% [markdown]
# ## Финальный вариант

# %% [markdown]
# Библиотеки:

# %%
import requests
from bs4 import BeautifulSoup

# %%
http_proxy = "http://162.214.118.137:80"
https_proxy = 'http://lum-customer-c_1b683750-zone-zone1-country-us:ktbhsk2mio4z@zproxy.lum-superproxy.io:22225'
proxies_dict = {
    "http": http_proxy,
    "https": https_proxy
}

# %%
response = requests.get('https://www.vons.com/shop/aisles.2053.html#', proxies=proxies_dict)

# %%
html_code = response.text
soup = BeautifulSoup(html_code, 'html.parser')

# %% [markdown]
# Категории первого уровня и их субкатегории:

# %%
soups = soup.find_all('div', 'col-12 col-sm-12 col-md-4 col-lg-4 col-xl-3')

# %%
categories_and_subcategories = {}
for category_and_subcategory in soups:
    category = category_and_subcategory.find('h2', 'product-title text-uppercase').text
    link_cur = 'https://www.vons.com' + category_and_subcategory.find_all('a')[-1]['href']
    response_cur = requests.get(link_cur, proxies=proxies_dict)
    subcategories = BeautifulSoup(response_cur.text, 'html.parser').find_all('h2', 'aisle-category')
    subcategories_text = []
    for subcategory in subcategories:
        subcategories_text.append(subcategory.text)
    categories_and_subcategories[category] = subcategories_text

categories_and_subcategories
# Out:
# {'Baby Care': ['Formula & Baby Food',
#   'Diapers & Wipes',
#   'Baby Bath & Skin Care',
#   'Baby Accessories'],
#  'Beverages': ['Juice & Smoothies',
#   'Coffee',
#   'Soft Drinks',
#   'Tea',
#   'Water & Sparkling Water',
#   'Energy Drinks & Shots',
#   'Sports Drinks',
#   'Kombucha',
#   'Coconut Water',
#   'Cocoa & Hot Chocolate'],
#  'Bread & Bakery': ['Cakes & Cupcakes',
#   'Cookies & Bakery Snacks',
#   'Desserts & Cheesecakes',
#   'Baguettes & French Bread',
#   'Breakfast & Donuts',
#   'Buns & Rolls',
#   'Sandwich Breads',
#   'Bagels & Muffins',
#   'Pitas & Flatbreads',
#   'Bakery Catering Trays'],
#  'Breakfast & Cereal': ['Cereal',
#   'Frozen Breakfast',
#   'Breakfast Bars & Bites',
#   'Pancake & Waffle Mix',
#   'Syrup',
#   'Toaster Pastries',
#   'Instant Breakfast Drink'],
#  'Canned Goods & Soups': ['Soups & Ramen',
#   'Canned Vegetables',
#   'Canned Seafood & Fish',
#   'Canned Beans',
#   'Canned Tomatoes',
#   'Canned Fruit',
# ...

# %% [markdown]
# Категории второго уровня и их субкатегории

# %% [markdown]
# Итак, ссылка на страничку категории первого уровня. Из нее надо достать ссылки на странички категорий второго уровня -> из них категории третьего уровня.

# %%
link_cur
# Out:
# 'https://www.vons.com/shop/aisles/wine-beer-spirits.2053.html'

# %%
first_level_category = BeautifulSoup(response_cur.text, 'html.parser')

# %%
second_level_categories = first_level_category.find_all('a', 'sbc-link')

# %%
second_level_categories[0]['data-aisle-name']
# Out:
# 'Wine'

# %%
second_level_category_link = 'https://www.vons.com' + second_level_categories[0]['href']

# %%
second_level_category_link
# Out:
# 'https://www.vons.com/shop/aisles/wine-beer-spirits/wine.2053.html'

# %%
second_level_category_response = requests.get(second_level_category_link, proxies=proxies_dict)

# %%
soup_ = BeautifulSoup(second_level_category_response.text, 'html.parser')

# %% [markdown]
# Кажется, нашел! (Проверить по интерфейсу сайта)

# %%
third_level_categories = soup_.find_all('span', "squaredThree department-filter-aisle")

# %%
'https://www.vons.com' + third_level_categories[0].a['href']
# Out:
# 'https://www.vons.com/shop/aisles/wine-beer-spirits/wine/wine-blends-other.2053.html'

# %%
third_level_categories[-1].a.text[0:-4]
# Out:
# 'Gewurztraminer'

# %% [markdown]
# В общем, все готово, осталось доделать словарь вида {2nd category: 3nd category}

# %% [markdown]
# Итак. Надо взять предыдущий цикл и доделать его, сделав 2 словаря: `12-lvl`, `23-lvl`.

# %%
import requests
from bs4 import BeautifulSoup

http_proxy = "http://162.214.118.137:80"
https_proxy = "http://lum-customer-c_1b683750-zone-zone1-country-us:ktbhsk2mio4z@zproxy.lum-superproxy.io:22225"
proxies_dict = {
    "http": http_proxy,
    "https": https_proxy
}

response = requests.get('https://www.vons.com/shop/aisles.2053.html#', proxies=proxies_dict)
html_code = response.text


first_second_level_categories_and_subcategories = {}
second_third_level_categories_and_subcategories = {}

first_level_categories_and_subcategories = BeautifulSoup(html_code, 'html.parser').find_all('div', 'col-12 col-sm-12 col-md-4 col-lg-4 col-xl-3'
for first_level_category_and_subcategory in soups:
    first_level_category = first_level_category_and_subcategory.find('h2', 'product-title text-uppercase').text
    link_cur = 'https://www.vons.com' + first_level_category_and_subcategory.find_all('a')[-1]['href']
    response_cur = requests.get(link_cur, proxies=proxies_dict)
    first_level_subcategories = BeautifulSoup(response_cur.text, 'html.parser').find_all('h2', 'aisle-category')
    subcategories_text = []
    for subcategory in first_level_subcategories:
        subcategories_text.append(subcategory.text)
    first_second_level_categories_and_subcategories[first_level_category] = subcategories_text

    second_level_categories = BeautifulSoup(response_cur.text, 'html.parser').find_all('a', 'sbc-link')
    for second_level_category in second_level_categories:
        second_level_category_link = 'https://www.vons.com' + second_level_category['href']
        second_level_category_response = requests.get(second_level_category_link, proxies=proxies_dict)
        second_level_subcategories = BeautifulSoup(second_level_category_response.text, 'html.parser')
        third_level_categories = second_level_subcategories.find_all('span', "squaredThree department-filter-aisle")
        subcategories_text = []
        for third_level_category in third_level_categories:
            subcategories_text.append(third_level_category.a.text[0:-4])
        second_third_level_categories_and_subcategories[second_level_category['data-aisle-name']] = subcategories_text
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-1e0c4443b60a> in <module>
#      31     for second_level_category in second_level_categories:
#      32         second_level_category_link = 'https://www.vons.com' + second_level_category['href']
# ---> 33         second_level_category_response = requests.get(second_level_category_link, proxies=proxies_dict)
#      34         second_level_subcategories = BeautifulSoup(second_level_category_response.text, 'html.parser')
#      35         third_level_categories = second_level_subcategories.find_all('span', "squaredThree department-filter-aisle")
#
# ~/miniconda3/lib/python3.9/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ...

# %%
first_second_level_categories_and_subcategories
# Out:
# {'Baby Care': ['Formula & Baby Food',
#   'Diapers & Wipes',
#   'Baby Bath & Skin Care',
#   'Baby Accessories'],
#  'Beverages': ['Juice & Smoothies',
#   'Coffee',
#   'Soft Drinks',
#   'Tea',
#   'Water & Sparkling Water',
#   'Energy Drinks & Shots',
#   'Sports Drinks',
#   'Kombucha',
#   'Coconut Water',
#   'Cocoa & Hot Chocolate'],
#  'Bread & Bakery': ['Cakes & Cupcakes',
#   'Cookies & Bakery Snacks',
#   'Desserts & Cheesecakes',
#   'Baguettes & French Bread',
#   'Breakfast & Donuts',
#   'Buns & Rolls',
#   'Sandwich Breads',
#   'Bagels & Muffins',
#   'Pitas & Flatbreads',
#   'Bakery Catering Trays'],
#  'Breakfast & Cereal': ['Cereal',
#   'Frozen Breakfast',
#   'Breakfast Bars & Bites',
#   'Pancake & Waffle Mix',
#   'Syrup',
#   'Toaster Pastries',
#   'Instant Breakfast Drink'],
#  'Canned Goods & Soups': ['Soups & Ramen',
#   'Canned Vegetables',
#   'Canned Seafood & Fish',
#   'Canned Beans',
#   'Canned Tomatoes',
#   'Canned Fruit',
# ...

# %%
second_third_level_categories_and_subcategories
# Out:
# {'Formula & Baby Food': ['2nd Foods',
#   'Toddler Bakery & Snacks',
#   'Baby Formula',
#   '1st Foods',
#   'Toddler Foods',
#   'Electrolyte Solution',
#   'Baby Cereal',
#   '3rd Foods',
#   'Baby Juice & Beverages',
#   'Nutritional Supplements'],
#  'Diapers & Wipes': ['Wipes & Diaper Refills',
#   'Training Pants',
#   'Diapers - Size 4',
#   'Diapers - Size 5',
#   'Diapers - Size 3',
#   'Diapers - Size 6 & Above',
#   'Diapers - Size 2',
#   'Diapers - Size 1',
#   'Diapers - Newborn'],
#  'Baby Bath & Skin Care': ['Baby Lotion & Oil',
#   'Baby Body Wash',
#   'Diaper Cream & Ointments',
#   'Baby Shampoo',
#   'Baby Powder'],
#  'Baby Accessories': ['Pacifiers & Teethers',
#   'Bottles & Nursing',
#   'Cups & Placeware',
#   'Toys & Accessories',
#   'Health & Safety'],
#  'Juice & Smoothies': ['Smoothies',
#   'Fruit Drink Mix',
#   'Orange Juice',
#   'Cranberry Juice',
#   'Berry & Blends',
#   'Juice Packs',
#   'Apple Juice & Cider',
#   'Lemonade & Limeade',
# ...

# %% [markdown]
# ## XPath guide

# %% [markdown]
# XPath (XML Path) — это язык запросов, для навигации по XML-документу и работы с его частями. Данный язык был создан W3C в 1999 году и используется в случаях, когда необходимо обработать XML-документ с помощью Python, Java или C\#.
#
# библиотека BeautifulSoup не поддерживает XPath, однако с ним очень удобно работать, используя другие библиотеки. Немотря на то, что XPath создан для работы с XML-документами, его также можно использовать и для работы с HTML-документами
#
# В основе синтаксиса XPath есть 4 основных концепта:
#
# - Различия в работе с корневыми и некорневыми вершинами
#     - `/div` выбирает вершину `div` только если она является корнем документа
#     - `//div` позволяет обращаться ко всем `div`'ам где угодно в любом месте в документе
#
# - Возможность выбора атрибутов
#     - `//@href` выберет все вершины с атрибутом `href`
#     - `//a[@href='http://google.com']` выберет все ссылки в документы, которые ведут на сайт Google
#
# - Возможность выбора вершин по позиции
#     - `//a[3]` выбирает третью ссылку в документе
#     - `//table[last()]` выбирает последнюю таблицу в документе
#     - `//a[position() < 3]` выбирает первые три ссылки в документе
#
# - Звездочка обозначает любой набор вершин или символов и может быть использована в различных ситуациях
#     - `//table/tr/*` выбирает всех потомков тега `tr` во всех таблицах
#     - `//div[@*]` выбирает все теги `div`, у которых етсь хоть какие-то атрибуты
#
# У XPath огромное число и более интересных возможностей. За годы развития XPath стал сложным языком запросов с логическими операциями, функциями и т. д. Хорошая документация по XPath есть у [Microsoft](https://docs.microsoft.com/en-us/previous-versions/dotnet/netframework-4.0/ms256471(v=vs.100)?redirectedfrom=MSDN)
